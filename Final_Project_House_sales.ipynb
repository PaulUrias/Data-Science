# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %% [markdown]
# # Module 1: Importing Data Sets

# %%
house_sales = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv')

# %%
house_sales.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# ## Question 1

# %% [markdown]
# Display the data types of each column using the function dtypes. Take a screenshot of your code and output. You will need to submit the screenshot for the final project.

# %%
house_sales.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# We use the method describe to obtain a statistical summary of the dataframe.

# %%
house_sales.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %% [markdown]
# # Module 2: Data Wrangling

# %% [markdown]
# ## Question 2

# %% [markdown]
# Drop the columns "id" and "Unnamed: 0" from axis 1 using the method drop(), then use the method describe() to obtain a statistical summary of the data. Make sure the inplace parameter is set to True. Take a screenshot of your code and output. You will need to submit the screenshot for the final project.

# %%
house_sales.drop(columns=['Unnamed: 0', 'id'], inplace=True)
house_sales.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# We can see we have missing values for the columns  bedrooms and  bathrooms

# %%
print("number of NaN values for the column bedrooms :", house_sales['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", house_sales['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 13
# number of NaN values for the column bathrooms : 10

# %% [markdown]
# We can replace the missing values of the column 'bedrooms' with the mean of the column 'bedrooms'  using the method replace()

# %%
avg_bedrooms = house_sales['bedrooms'].mean()
house_sales['bedrooms'] = house_sales['bedrooms'].replace(np.nan, avg_bedrooms)

# %% [markdown]
# We also replace the missing values of the column 'bathrooms' with the mean of the column 'bathrooms'  using the method replace()

# %%
avg_bathrooms = house_sales['bathrooms'].mean()
house_sales['bathrooms'] = house_sales['bathrooms'].replace(np.nan, avg_bathrooms)

# %%
print("number of NaN values for the column bedrooms :", house_sales['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", house_sales['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 0
# number of NaN values for the column bathrooms : 0

# %% [markdown]
# # Module 3: Exploratory Data Analysis

# %% [markdown]
# ## Question 3

# %% [markdown]
# Use the method value_counts to count the number of houses with unique floor values, use the method .to_frame() to convert it to a data frame.\
# Take a screenshot of your code and output. You will need to submit the screenshot for the final project.

# %%
floors = house_sales['floors'].value_counts()
floors_df=floors.to_frame()
floors_df.rename(columns={'count':'Conteo_houses'}, inplace=True)
floors_df.reset_index()
# Out:
#    floors  Conteo_houses
# 0     1.0          10680
# 1     2.0           8241
# 2     1.5           1910
# 3     3.0            613
# 4     2.5            161
# 5     3.5              8

# %% [markdown]
# ## Question 4

# %% [markdown]
# Use the function boxplot in the seaborn library to determine whether houses with a waterfront view or without a waterfront view have more price outliers.\
# Take a screenshot of your code and boxplot. You will need to submit the screenshot for the final project.

# %%
sns.boxplot(x=house_sales['waterfront'], y=house_sales['price'])
plt.ylabel("Price (Millions)")
# Out:
# Text(0, 0.5, 'Price (Millions)')

# %% [markdown]
# ## Question 5

# %% [markdown]
# Use the function regplot in the seaborn library to determine if the feature sqft_above is negatively or positively correlated with price.\
# Take a screenshot of your code and scatterplot. You will need to submit the screenshot for the final project.

# %%
sns.regplot(x=house_sales['sqft_above'], y=house_sales['price'], line_kws={'color':'red'})
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %% [markdown]
# We can use the Pandas method corr() to find the feature other than price that is most correlated with price.

# %%
hs_numeric = house_sales._get_numeric_data()
hs_numeric.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525738
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %% [markdown]
# # Module 4: Model Development

# %% [markdown]
# We can Fit a linear regression model using the longitude feature 'long' and caculate the R^2.

# %%
X = house_sales[['long']]
y = house_sales['price']
lm = LinearRegression()
lm.fit(X,y)
lm.score(X, y)
# Out:
# 0.00046769430149007363

# %% [markdown]
# ## Question 6

# %% [markdown]
# Fit a linear regression model to predict the 'price' using the feature 'sqft_living' then calculate the R^2.\
# Take a screenshot of your code and the value of the R^2. You will need to submit it for the final project.

# %%
x = house_sales[['sqft_living']]
y = house_sales['price']

lm2 = LinearRegression()
lm2.fit(x, y)
print('The value of R^2 is:', lm2.score(x, y))
# Out:
# The value of R^2 is: 0.4928532179037931

# %% [markdown]
# ## Question 7

# %% [markdown]
# Fit a linear regression model to predict the 'price' using the list of features:

# %%
features = house_sales[["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]]

# %% [markdown]
# Then calculate the R^2. Take a screenshot of your code and the value of the R^2. You will need to submit it for the final project

# %%
mlr = LinearRegression()
mlr.fit(features, y)
print('The value of R^2 is:', mlr.score(features, y))
# Out:
# The value of R^2 is: 0.6576951666037502

# %% [markdown]
# ### This will help with Question 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Input = [('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %% [markdown]
# ## Question 8

# %% [markdown]
# Use the list to create a pipeline object to predict the 'price', fit the object using the features in the list features, and calculate the R^2.\
# Take a screenshot of your code and the value of the R^2. You will need to submit it for the final project.

# %%
pipe = Pipeline(Input)
pipe.fit(features, y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
y_predicted = pipe.predict(features)
print('The value of R^2 is:', r2_score(y, y_predicted)) # way 1
# Out:
# The value of R^2 is: 0.7513404101380663

# %%
print('The value of R^2 is:',pipe.score(features, y)) # way 2
# Out:
# The value of R^2 is: 0.7513404101380663

# %% [markdown]
# # Module 5: Model Evaluation and Refinement

# %% [markdown]
# We will split the data into training and testing sets:

# %%
features = ["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]    
X = house_sales[features]
Y = house_sales['price']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

print("number of test samples:", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples: 3242
# number of training samples: 18371

# %% [markdown]
# ## Question 9

# %% [markdown]
# Create and fit a Ridge regression object using the training data, set the regularization parameter to 0.1, and calculate the R^2 using the test data.\
# Take a screenshot of your code and the value of the R^2. You will need to submit it for the final project.

# %%
ridge = Ridge(alpha=0.1)
ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
print('The value of R^2 is:', ridge.score(x_test, y_test)) # way 1
# Out:
# The value of R^2 is: 0.6478759163939112

# %%
y_ridge_pred = ridge.predict(x_test)
print('The value of R^2 is:', r2_score(y_test, y_ridge_pred)) # way 2
# Out:
# The value of R^2 is: 0.6478759163939112

# %% [markdown]
# ## Question 10

# %% [markdown]
# Perform a second order polynomial transform on both the training data and testing data. Create and fit a Ridge regression object using the training data,\
# set the regularisation parameter to 0.1, and calculate the R^2 utilising the test data provided.\
# Take a screenshot of your code and the R^2. You will need to submit it for the final project

# %%
plnml = PolynomialFeatures(degree=2)
x_train_plnml = plnml.fit_transform(x_train)
x_test_plnml = plnml.fit_transform(x_test)

# %%
ridge2 = Ridge(alpha=0.1)
ridge2.fit(x_train_plnml, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
print('The value of R^2 is:', ridge2.score(x_test_plnml, y_test))
# Out:
# The value of R^2 is: 0.7002744259992879

# %%
y_pred_pol_ridg = ridge2.predict(x_test_plnml)
r2_score(y_test, y_pred_pol_ridg)
# Out:
# 0.7002744259992879
